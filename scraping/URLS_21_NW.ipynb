# %%
# import packages
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import StaleElementReferenceException
import time 
import os
import json
import urllib

# %%
# Some urls are blocked from untrusted sites, the below code make python environment to trust every site
import os, ssl
if (not os.environ.get('PYTHONHTTPSVERIFY', '') and
getattr(ssl, '_create_unverified_context', None)):
    ssl._create_default_https_context = ssl._create_unverified_context

# %%
def download_images():
    
    f = open('site_urls.txt','r')
    search_url = f.readlines()[21]
    print(search_url)
   
    # path of chorme drive to run selenium
    path = r'chromedriver'
    
    driver = webdriver.Chrome(path)
    
    k = open('wildlife keywords.txt','r')
    kw = k.readlines()
    
    for i in range(0,2):
        print(i)
        keyW = kw[i]
        
        driver.get(search_url)

        #driver.find_element_by_xpath('//*[@id="ib-main-content"]/div[2]/div[2]/div/div/div[2]/span/a').click()
        time.sleep(2)

        box = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div[2]/div[1]/div[2]/div[3]/form/div[1]/div[2]/input')  
        box.clear()
        box.send_keys(keyW)
        time.sleep(2)
        try:
            links = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div[3]/div/div[2]/div[3]/div[2]')
            sub_lnks = links.find_elements_by_tag_name('a')

            lnks_lst = []

            for lnk in sub_lnks:
                lnks_lst.append(lnk.get_attribute('href'))
            print(lnks_lst[0:3])

        #try:
            if lnks_lst:
                if not os.path.exists(str(21)+'_'+str(i)):
                    os.mkdir(str(21)+'_'+str(i))
            for j in range(1,3):
                driver.get(lnks_lst[j])
                print(lnks_lst[j])
                time.sleep(2)
                sub_txt = driver.find_element_by_xpath('//*[@id="product_addtocart_form"]/div[5]/h2').text
                if not os.path.exists(str(21)+'_'+str(i) +'/'+ str(j)):
                    os.mkdir(str(21)+'_'+str(i) +'/'+ str(j))
                details = {
                    'name' : sub_txt,
                    'price' : driver.find_element_by_xpath('/html/body/div/div[1]/div[3]/div/div/div[3]/div[1]/form/div[7]/div/div[2]').get_attribute("innerText"),
                    'location': None,
                    'details': driver.find_element_by_xpath('//*[@id="product_addtocart_form"]/div[7]/div/ul').get_attribute("innerText"),
                    'description' : driver.find_element_by_xpath('//*[@id="product_tabs_description_contents"]/div[1]/div').get_attribute("innerText"),
                    'url' : search_url
                }
                with open(str(21)+'_'+str(i) +'/'+ str(j) + '/' + str(j) + '.txt', 'w') as tfile:
                     tfile.write(json.dumps(details))

                image_lst = []
                elem1 = driver.find_element_by_xpath('//*[@id="product_addtocart_form"]/div[6]/div/div[2]/div')
                sub = elem1.find_elements_by_tag_name('a')
                for k,l in enumerate(sub):
                    href = l.get_attribute('href')
                    image_lst.append(href)
                    print(href)
                    if href != None:
                        urllib.request.urlretrieve(str(href), os.path.join(str(21)+'_'+str(i), str(j), str(j)+'_'+str(k)+'.jpg'))
                with open(str(21)+'_'+str(i) +'/'+ str(j) + '/' + str(j) + '_imgs.txt', 'w') as tfile:
                     tfile.write(json.dumps(image_lst)) 
        except:
            continue
            
    driver.close()

# %%
def main():
    download_images()
    
if __name__ == "__main__":
    main()
# Out:
# http://www.worthpoint.com/inventory/search?query=[KW]&currencyCode=USD&channels={}&max=100&sort=BestMatch&absoluteMax=201520&layout=grid&saleLocation=US&searchForm=search&restrictTo=worldwide&_img=&img=on
#
# 0
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-4-df67b04b3ad5> in <module>
#       3
#       4 if __name__ == "__main__":
# ----> 5     main()
#
# <ipython-input-4-df67b04b3ad5> in main()
#       1 def main():
# ----> 2     download_images()
#       3
#       4 if __name__ == "__main__":
#       5     main()
#
# <ipython-input-3-95ac98d99e01> in download_images()
#      22         time.sleep(2)
#      23
# ---> 24         box = driver.find_element_by_xpath('/html/body/div[1]/div[1]/div[2]/div[1]/div[2]/div[3]/form/div[1]/div[2]/input')
#      25         box.clear()
#      26         box.send_keys(keyW)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#     980     def find_elements(self, by=By.ID, value=None):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/div[1]/div[1]/div[2]/div[1]/div[2]/div[3]/form/div[1]/div[2]/input"}
#   (Session info: chrome=105.0.5195.125)
