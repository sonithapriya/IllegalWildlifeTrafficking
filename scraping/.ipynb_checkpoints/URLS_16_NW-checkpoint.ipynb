# %%
# import packages
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import StaleElementReferenceException
import time 
import os
import json
import urllib

# %%
# Some urls are blocked from untrusted sites, the below code make python environment to trust every site
import os, ssl
if (not os.environ.get('PYTHONHTTPSVERIFY', '') and
getattr(ssl, '_create_unverified_context', None)):
    ssl._create_default_https_context = ssl._create_unverified_context

# %%
def download_images():
    
    f = open('site_urls.txt','r')
    search_url = f.readlines()[16]
    print(search_url)
   
    # path of chorme drive to run selenium
    path = r'chromedriver'
    
    driver = webdriver.Chrome(path)
    
    k = open('wildlife keywords.txt','r')
    kw = k.readlines()
    
    for i in range(0,2):
        print(i)
        keyW = kw[i]
        
        driver.get(search_url)

        #driver.find_element_by_xpath('//*[@id="ib-main-content"]/div[2]/div[2]/div/div/div[2]/span/a').click()
        time.sleep(2)
        driver.find_element_by_xpath('//*[@id="js-header"]/header/div[1]/div[2]/div/div[1]/div/form/div/div/div/div/div[2]/div[1]/button').click()
        time.sleep(2)
        box = driver.find_element_by_xpath('//*[@id="input-:headerR1ai:"]') 
        box.send_keys(keyW)
        time.sleep(5)
        #try:
        links = driver.find_element_by_xpath('/html/body/div[2]/main/div/div[3]/div[2]/div[2]')
        sub_lnks = links.find_elements_by_tag_name('a')

        lnks_lst = []

        for lnk in sub_lnks:
            lnks_lst.append(lnk.get_attribute('href'))
        print(lnks_lst[0:3])

    #try:
        if lnks_lst:
            if not os.path.exists(str(16)+'_'+str(i)):
                os.mkdir(str(16)+'_'+str(i))
        for j in range(1,3):
            driver.get(lnks_lst[j])
            print(lnks_lst[j])
            time.sleep(2)
            sub_txt = driver.find_element_by_xpath('//*[@id="js-root"]/div/div[4]/div[2]/div/div[1]/div[1]/h1/div').text
            if not os.path.exists(str(16)+'_'+str(i) +'/'+ str(j)):
                os.mkdir(str(16)+'_'+str(i) +'/'+ str(j))
            details = {
                'name' : sub_txt,
                'price' : driver.find_element_by_xpath('//*[@id="js-root"]/div/div[4]/div[2]/div/div[2]/div[1]/div/span[1]').text,
                'location': driver.find_element_by_xpath('//*[@id="js-root"]/div/div[5]/div[1]/div/div[2]/div/ul/li[5]/div[2]/span/span').text,
                'details': driver.find_element_by_xpath('//*[@id="js-root"]/div/div[5]/div[1]/div/div[2]').get_attribute("innerText"),
                'description' : driver.find_element_by_xpath('//*[@id="js-root"]/div/div[5]/div[1]/div/div[1]').get_attribute("innerText"),
                'url' : search_url
            }
            with open(str(16)+'_'+str(i) +'/'+ str(j) + '/' + str(j) + '.txt', 'w') as tfile:
                 tfile.write(json.dumps(details))

            image_lst = []
            elem1 = driver.find_element_by_xpath('//*[@id="js-root"]/div/div[4]/div[1]/div[1]/div/div[2]/div[3]/div')
            sub = elem1.find_elements_by_tag_name('img')
            for k,l in enumerate(sub):
                src = l.get_attribute('src')
                image_lst.append(src)
                print(src)
                if src != None:
                    urllib.request.urlretrieve(str(src), os.path.join(str(16)+'_'+str(i), str(j), str(j)+'_'+str(k)+'.jpg'))
            with open(str(16)+'_'+str(i) +'/'+ str(j) + '/' + str(j) + '_imgs.txt', 'w') as tfile:
                 tfile.write(json.dumps(image_lst)) 
        #except:
            #continue
            
    #driver.close()

# %%
def main():
    download_images()
    
if __name__ == "__main__":
    main()
# Out:
# https://www.1stdibs.com/search/?q=[KW]&sort=price-high
#
# 0
# [None, None, None]
# ---------------------------------------------------------------------------
# InvalidArgumentException                  Traceback (most recent call last)
# <ipython-input-9-df67b04b3ad5> in <module>
#       3
#       4 if __name__ == "__main__":
# ----> 5     main()
#
# <ipython-input-9-df67b04b3ad5> in main()
#       1 def main():
# ----> 2     download_images()
#       3
#       4 if __name__ == "__main__":
#       5     main()
#
# <ipython-input-8-ee81e34b4c22> in download_images()
#      41                 os.mkdir(str(16)+'_'+str(i))
#      42         for j in range(1,3):
# ---> 43             driver.get(lnks_lst[j])
#      44             print(lnks_lst[j])
#      45             time.sleep(2)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
# ...

# %%
//*[@id="js-root"]/div[3]/div[2]/div[2]/div[1]/div[1]/div/div/div[2]/div[2]/div/div/div/ul/li[2]/a
//*[@id="js-root"]/div[3]/div[2]/div[2]/div[1]/div[2]/div/div/div[2]/div[2]/div/div/div/ul/li[2]/a
//*[@id="js-root"]/div[3]/div[2]/div[2]/div[1] 
//*[@id="js-root"]/div[3]/div[2]/div[2]/div[1]/div[1]/div/div/div[2]/div[2]/div/div/div/ul/li[2]/a
