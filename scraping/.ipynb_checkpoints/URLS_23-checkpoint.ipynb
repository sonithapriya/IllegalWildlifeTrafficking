# %%
# import packages
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import StaleElementReferenceException
import time 
import os
import json
import urllib

# %%
# Some urls are blocked from untrusted sites, the below code make python environment to trust every site
import os, ssl
if (not os.environ.get('PYTHONHTTPSVERIFY', '') and
getattr(ssl, '_create_unverified_context', None)):
    ssl._create_default_https_context = ssl._create_unverified_context

# %%
def download_images():
    
    f = open('site_urls.txt','r')
    search_url = f.readlines()[23]
    print(search_url)
   
    # path of chorme drive to run selenium
    path = r'chromedriver'
    
    driver = webdriver.Chrome(path)
    
    k = open('wildlife keywords.txt','r')
    kw = k.readlines()
    
    for i in range(0,len(kw)):
        print(i)
        keyW = kw[i]
        
        driver.get(search_url)
        
        # X mark clicking in search text box
        driver.find_element_by_xpath('//*[@id="navbar-search"]/form/div/span[1]/a').click()
        time.sleep(2)
        
        # search text box
        box = driver.find_element_by_xpath('//*[@id="main_ss"]')  
        
        #sending the keyword
        box.send_keys(keyW)
        time.sleep(2)
        
        # try block if there are no ad results for the keyword it will continue with next keyword
        try:
            # collecting links of ad results
            links = driver.find_element_by_xpath('//*[@id="maincontent"]/div/div/div/div/div[4]')
            sub_lnks = links.find_elements_by_tag_name('a')

            lnks_lst = []

            for lnk in sub_lnks:
                lnks_lst.append(lnk.get_attribute('href'))
            print(lnks_lst[0:3])

            # making a directory like URL+Keyword_number , example 23_0 , 23_1,...
            if lnks_lst:
                if not os.path.exists(str(23)+'_'+str(i)):
                    os.mkdir(str(23)+'_'+str(i))
                    
            #  iterating through ads results
            for j in range(1,3):
                driver.get(lnks_lst[j])
                print(lnks_lst[j])
                time.sleep(2)
                # Title capturing 
                sub_txt = driver.find_element_by_xpath('//*[@id="item-desc"]/div[1]/div/p[1]').text
                #making directory inside the above created directory like 0 means first ad, 1 for second ad....
                if not os.path.exists(str(23)+'_'+str(i) +'/'+ str(j)):
                    os.mkdir(str(23)+'_'+str(i) +'/'+ str(j))
                # making dictionary
                details = {
                    'name' : sub_txt,
                    'price' : driver.find_element_by_xpath('//*[@id="item-price"]/span').text,
                    'location': None,
                    'details': driver.find_element_by_xpath('//*[@id="item-desc"]').get_attribute("innerText"),
                    'description' : None,
                    'url' : lnks_lst[j]
                }
                # writing the dictionary to text file like 0.txt for first ad ....
                with open(str(23)+'_'+str(i) +'/'+ str(j) + '/' + str(j) + '.txt', 'w') as tfile:
                     tfile.write(json.dumps(details))
                
                # collecting image urls
                image_lst = []
                elem1 = driver.find_element_by_xpath('//*[@id="item-main-group"]/div[2]/div[2]/div[1]')
                sub = elem1.find_elements_by_tag_name('img')
                for k,l in enumerate(sub):
                    src = l.get_attribute('src')
                    image_lst.append(src)
                    print(src)
                    # collecting images and saving it inside the above created directory like 0_0.jpg for first ad first image
                    # 0_1.jpg for first ad second image ...
                    if src != None:
                        urllib.request.urlretrieve(str(src), os.path.join(str(23)+'_'+str(i), str(j), str(j)+'_'+str(k)+'.jpg'))
                # writing image urls to text file like 0_imgs.txt for first ad ....
                with open(str(23)+'_'+str(i) +'/'+ str(j) + '/' + str(j) + '_imgs.txt', 'w') as tfile:
                     tfile.write(json.dumps(image_lst)) 
        except:
            continue
            
    driver.close()

# %%
def main():
    download_images()
    
if __name__ == "__main__":
    main()
# Out:
# http://www.rubylane.com/ni/search?q=[KW]&sort=pricehigh&style=3&cstyle=1ttp://www.auctionzip.com/cgi-bin/auctionsearch.cgi?txtSearchRadius=0&txtSearchZip=&idxSearchCategory=0&txtSearchKeywords=[KW]&month=&year=&searchPath=head&newsearch=1
#
# 0
# ['http://www.rubylane.com/item/2189286-T2308moted/Authenticx21-Kieselstein-Cord-18k-Yellow-Gold?search=1&t=85a9f3fc', 'http://www.rubylane.com/item/2189286-T2308moted/Authenticx21-Kieselstein-Cord-18k-Yellow-Gold?search=1&t=f603b1bb', 'http://www.rubylane.com/item/2189286-Ti684eaed/Authenticx21-Kieselstein-Cord-18k-Yellow-Gold?search=1&t=f1a44b4e']
# http://www.rubylane.com/item/2189286-T2308moted/Authenticx21-Kieselstein-Cord-18k-Yellow-Gold?search=1&t=f603b1bb
# https://cdn0.rubylane.com/_pod/item/2189286/T2308moted/Authenticx7821-Kieselstein-Cord-18k-Yellow-Gold-thumb-1A-130-f7e76dd0-f.webp
# https://cdn0.rubylane.com/_pod/item/2189286/T2308moted/Authenticx7821-Kieselstein-Cord-18k-Yellow-Gold-thumb-1o-130-f7e76dd0-f.webp
# https://cdn0.rubylane.com/_pod/item/2189286/T2308moted/Authenticx7821-Kieselstein-Cord-18k-Yellow-Gold-thumb-2o-130-39d46134-f.webp
# https://cdn0.rubylane.com/_pod/item/2189286/T2308moted/Authenticx7821-Kieselstein-Cord-18k-Yellow-Gold-thumb-3o-130-51410262-f.webp
# https://cdn0.rubylane.com/_pod/item/2189286/T2308moted/Authenticx7821-Kieselstein-Cord-18k-Yellow-Gold-thumb-4o-130-15babf83-f.webp
# https://cdn0.rubylane.com/_pod/item/2189286/T2308moted/Authenticx7821-Kieselstein-Cord-18k-Yellow-Gold-thumb-5o-130-15ade47f-f.webp
# https://cdn0.rubylane.com/_pod/item/2189286/T2308moted/Authenticx7821-Kieselstein-Cord-18k-Yellow-Gold-thumb-6o-130-936b40cb-f.webp
# https://cdn0.rubylane.com/_pod/item/2189286/T2308moted/Authenticx7821-Kieselstein-Cord-18k-Yellow-Gold-thumb-7o-130-a2bf357c-f.webp
# https://cdn0.rubylane.com/_pod/item/2189286/T2308moted/Authenticx7821-Kieselstein-Cord-18k-Yellow-Gold-thumb-8o-130-d614840a-f.webp
# https://cdn0.rubylane.com/_pod/item/2189286/T2308moted/Authenticx7821-Kieselstein-Cord-18k-Yellow-Gold-thumb-9o-130-c0ee86a9-f.webp
# https://cdn0.rubylane.com/_pod/item/2189286/T2308moted/Authenticx7821-Kieselstein-Cord-18k-Yellow-Gold-thumb-10o-130-c3a28c9e-f.webp
# https://cdn0.rubylane.com/_pod/item/2189286/T2308moted/Authenticx7821-Kieselstein-Cord-18k-Yellow-Gold-thumb-11o-130-34c90a53-f.webp
# https://cdn0.rubylane.com/_pod/item/2189286/T2308moted/Authenticx7821-Kieselstein-Cord-18k-Yellow-Gold-thumb-12o-130-54b59664-f.webp
# http://www.rubylane.com/item/2189286-Ti684eaed/Authenticx21-Kieselstein-Cord-18k-Yellow-Gold?search=1&t=f1a44b4e
# https://cdn0.rubylane.com/_pod/item/2189286/Ti684eaed/Authenticx7821-Kieselstein-Cord-18k-Yellow-Gold-thumb-1A-130-7e9d183c-f.webp
# https://cdn0.rubylane.com/_pod/item/2189286/Ti684eaed/Authenticx7821-Kieselstein-Cord-18k-Yellow-Gold-thumb-1o-130-7e9d183c-f.webp
# https://cdn0.rubylane.com/_pod/item/2189286/Ti684eaed/Authenticx7821-Kieselstein-Cord-18k-Yellow-Gold-thumb-2o-130-2ae8f2be-f.webp
# https://cdn0.rubylane.com/_pod/item/2189286/Ti684eaed/Authenticx7821-Kieselstein-Cord-18k-Yellow-Gold-thumb-3o-130-afcebc24-f.webp
# https://cdn0.rubylane.com/_pod/item/2189286/Ti684eaed/Authenticx7821-Kieselstein-Cord-18k-Yellow-Gold-thumb-4o-130-ffb14cb8-f.webp
# https://cdn0.rubylane.com/_pod/item/2189286/Ti684eaed/Authenticx7821-Kieselstein-Cord-18k-Yellow-Gold-thumb-5o-130-e6044d86-f.webp
# https://cdn0.rubylane.com/_pod/item/2189286/Ti684eaed/Authenticx7821-Kieselstein-Cord-18k-Yellow-Gold-thumb-6o-130-43ad73c8-f.webp
# https://cdn0.rubylane.com/_pod/item/2189286/Ti684eaed/Authenticx7821-Kieselstein-Cord-18k-Yellow-Gold-thumb-7o-130-d340cb77-f.webp
# https://cdn0.rubylane.com/_pod/item/2189286/Ti684eaed/Authenticx7821-Kieselstein-Cord-18k-Yellow-Gold-thumb-8o-130-18061e45-f.webp
# https://cdn0.rubylane.com/_pod/item/2189286/Ti684eaed/Authenticx7821-Kieselstein-Cord-18k-Yellow-Gold-thumb-9o-130-1d265329-f.webp
# https://cdn0.rubylane.com/_pod/item/2189286/Ti684eaed/Authenticx7821-Kieselstein-Cord-18k-Yellow-Gold-thumb-10o-130-70df2021-f.webp
# https://cdn0.rubylane.com/_pod/item/2189286/Ti684eaed/Authenticx7821-Kieselstein-Cord-18k-Yellow-Gold-thumb-11o-130-92fa4258-f.webp
# https://cdn0.rubylane.com/_pod/item/2189286/Ti684eaed/Authenticx7821-Kieselstein-Cord-18k-Yellow-Gold-thumb-12o-130-0877d02c-f.webp
# 1
# ['http://www.rubylane.com/item/1356998-10317/Animals-Bone-China-Miniature-Giraffes-Hippopotamus?search=1&t=ea1782bc', 'http://www.rubylane.com/item/1356998-10317/Animals-Bone-China-Miniature-Giraffes-Hippopotamus?search=1&t=a4f25e19']
# http://www.rubylane.com/item/1356998-10317/Animals-Bone-China-Miniature-Giraffes-Hippopotamus?search=1&t=a4f25e19
# https://cdn0.rubylane.com/_pod/item/1356998/10317/Animals-Bone-China-Miniature-Giraffes-Hippopotamus-thumb-1A-130-00000000-ededed.webp
# https://cdn0.rubylane.com/_pod/item/1356998/10317/Animals-Bone-China-Miniature-Giraffes-Hippopotamus-thumb-1o-130-00000000-ededed.webp
# https://cdn0.rubylane.com/_pod/item/1356998/10317/Animals-Bone-China-Miniature-Giraffes-Hippopotamus-thumb-2o-130-00000000-ededed.webp
# https://cdn0.rubylane.com/_pod/item/1356998/10317/Animals-Bone-China-Miniature-Giraffes-Hippopotamus-thumb-3o-130-00000000-ededed.webp
# https://cdn0.rubylane.com/_pod/item/1356998/10317/Animals-Bone-China-Miniature-Giraffes-Hippopotamus-thumb-4o-130-00000000-ededed.webp
# https://cdn0.rubylane.com/_pod/item/1356998/10317/Animals-Bone-China-Miniature-Giraffes-Hippopotamus-thumb-5o-130-00000000-ededed.webp
# https://cdn0.rubylane.com/_pod/item/1356998/10317/Animals-Bone-China-Miniature-Giraffes-Hippopotamus-thumb-6o-130-65bd573f-ededed.webp
# https://cdn0.rubylane.com/_pod/item/1356998/10317/Animals-Bone-China-Miniature-Giraffes-Hippopotamus-thumb-7o-130-00000000-ededed.webp
# https://cdn0.rubylane.com/_pod/item/1356998/10317/Animals-Bone-China-Miniature-Giraffes-Hippopotamus-thumb-8o-130-00000000-ededed.webp
# https://cdn0.rubylane.com/_pod/item/1356998/10317/Animals-Bone-China-Miniature-Giraffes-Hippopotamus-thumb-9o-130-00000000-ededed.webp
# https://cdn0.rubylane.com/_pod/item/1356998/10317/Animals-Bone-China-Miniature-Giraffes-Hippopotamus-thumb-10o-130-00000000-ededed.webp
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-df67b04b3ad5> in <module>
#       3
#       4 if __name__ == "__main__":
# ----> 5     main()
#
# <ipython-input-5-df67b04b3ad5> in main()
#       1 def main():
# ----> 2     download_images()
#       3
#       4 if __name__ == "__main__":
#       5     main()
#
# <ipython-input-4-7c3efbed3e83> in download_images()
#      41                 os.mkdir(str(23)+'_'+str(i))
#      42         for j in range(1,3):
# ---> 43             driver.get(lnks_lst[j])
#      44             print(lnks_lst[j])
#      45             time.sleep(2)
#
# IndexError: list index out of range
